# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("C:/Users/DELL/Documents/UK/Accidents0514.csv")

# Display the first few rows of the dataset
data.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3964\2909525265.py:4: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:/Users/DELL/Documents/UK/Accidents0514.csv")
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  200501BS00001               525680.0                178240.0  -0.191170
# 1  200501BS00002               524170.0                181650.0  -0.211708
# 2  200501BS00003               524520.0                182240.0  -0.206458
# 3  200501BS00004               526900.0                177530.0  -0.173862
# 4  200501BS00005               528060.0                179040.0  -0.156618
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.489096             1                  2                   1
# 1  51.520075             1                  3                   1
# 2  51.525301             1                  3                   2
# ...

# %%
# Handle missing values (example strategy: drop rows with missing values)
data.dropna(inplace=True)

# Remove duplicate rows
data.drop_duplicates(inplace=True)

# Standardize date-time format
data['Date'] = pd.to_datetime(data['Date'] + ' ' + data['Time'], format='%d/%m/%Y %H:%M')

# Display summary statistics
data.describe(include='all')
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# count         1519998           1.519998e+06            1.519998e+06
# unique        1519998                    NaN                     NaN
# top     200501BS00001                    NaN                     NaN
# freq                1                    NaN                     NaN
# mean              NaN           4.509906e+05            2.708466e+05
# min               NaN           9.018000e+04            1.029000e+04
# 25%               NaN           3.897500e+05            1.760600e+05
# 50%               NaN           4.499000e+05            2.409290e+05
# 75%               NaN           5.257400e+05            3.826700e+05
# max               NaN           6.555400e+05            1.189600e+06
# std               NaN           8.863670e+04            1.244223e+05
#
#            Longitude      Latitude  Police_Force  Accident_Severity  \
# count   1.519998e+06  1.519998e+06  1.519998e+06       1.519998e+06
# ...

# %%
# Summary statistics
data.describe(include='all')
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# count         1519998           1.519998e+06            1.519998e+06
# unique        1519998                    NaN                     NaN
# top     200501BS00001                    NaN                     NaN
# freq                1                    NaN                     NaN
# mean              NaN           4.509906e+05            2.708466e+05
# min               NaN           9.018000e+04            1.029000e+04
# 25%               NaN           3.897500e+05            1.760600e+05
# 50%               NaN           4.499000e+05            2.409290e+05
# 75%               NaN           5.257400e+05            3.826700e+05
# max               NaN           6.555400e+05            1.189600e+06
# std               NaN           8.863670e+04            1.244223e+05
#
#            Longitude      Latitude  Police_Force  Accident_Severity  \
# count   1.519998e+06  1.519998e+06  1.519998e+06       1.519998e+06
# ...

# %%
import matplotlib.pyplot as plt

# Extract hour, day of the week, and month from the accident_date
data['hour'] = data['Date'].dt.hour
data['day_of_week'] = data['Date'].dt.dayofweek
data['month'] = data['Date'].dt.month

# Plot histograms
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
data['hour'].value_counts().sort_index().plot(kind='bar')
plt.title('Accidents by Hour of Day')
plt.xlabel('Hour')
plt.ylabel('Number of Accidents')

plt.subplot(1, 3, 2)
data['day_of_week'].value_counts().sort_index().plot(kind='bar')
plt.title('Accidents by Day of Week')
plt.xlabel('Day')
plt.ylabel('Number of Accidents')

plt.subplot(1, 3, 3)
data['month'].value_counts().sort_index().plot(kind='bar')
plt.title('Accidents by Month')
plt.xlabel('Month')
plt.ylabel('Number of Accidents')

plt.tight_layout()
plt.show()

# %%
# Plot bar charts for road and weather conditions
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
data['Road_Surface_Conditions'].value_counts().plot(kind='bar')
plt.title('Accidents by Road Condition')
plt.xlabel('Road Condition')
plt.ylabel('Number of Accidents')

plt.subplot(1, 2, 2)
data['Weather_Conditions'].value_counts().plot(kind='bar')
plt.title('Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')

plt.tight_layout()
plt.show()

# %%
! pip install pandas matplotlib folium scikit-learn
